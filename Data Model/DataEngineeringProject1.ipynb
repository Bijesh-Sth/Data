# %% [markdown]
# # Project: Data Modeling and Database Population
#
# This project involves the creation of a data model, table creation using Python, and the insertion of data from various datasets into a database. Below are the steps involved in this project:
#
# ## 1. Find Datasets from Various Links
#
# The first step is to locate datasets from various sources. These datasets may be available online, through APIs, or provided by stakeholders. The datasets should be relevant to the project requirements and should contain the necessary information for analysis.
#
# ## 2. Build Data Model
#
# Once the datasets are collected, the next step is to build a data model. This involves identifying the entities, attributes, and relationships present in the datasets. A clear understanding of the data structure is essential for effective data modeling.
#
# ## 3. Create Tables Using Python
#
# Using Python, tables will be created in a relational database management system (RDBMS) such as MySQL, PostgreSQL, or SQLite. The table schema will be designed based on the data model created in the previous step. Python libraries such as SQLAlchemy or psycopg2 can be utilized for this purpose.
#
# ## 4. Insert Data from the Files to Database
#
# After the tables are created, the data from the datasets will be inserted into the database tables. This process involves parsing the dataset files, transforming the data as necessary, and inserting it into the appropriate tables. Python scripts will be used to automate this process, ensuring efficient and accurate data population.

# %%
import psycopg2
import pandas as pd

# %%
#function to create a database and return a cursor and connection object
def create_database():
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=root")
    conn.set_session(autocommit=True)
    cur = conn.cursor()

    #creating database
    cur.execute("DROP DATABASE IF EXISTS firstdb")
    cur.execute("CREATE DATABASE firstdb")

    conn.close()

    #connect to the database
    conn = psycopg2.connect("host=127.0.0.1 dbname=firstdb user=postgres password=root")
    cur = conn.cursor()

    return cur, conn

# %%
#function to drop tables
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
AccountsCountry = pd.read_csv('Data/AccountsCountry.csv')

# %%
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# 2                                    2020 (expected)
# 3                                               2016
# 4  2011. Population figures compiled from adminis...
#
#                       Latest household survey  \
# 0      Demographic and Health Survey, 2017/18
# 1  Multiple Indicator Cluster Survey, 2019/20
# 2      Demographic and Health Survey, 2015/16
# 3                                         NaN
# 4                                         NaN
#
#                                        Special Notes  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  Fiscal year end: June 30; reporting period for...  ...
# 4  A simple multiplier is used to convert the nat...  ...
#
#    Source of most recent Income and expenditure data  \
# 0  Living Standards Measurement Study Survey (LSM...
# 1            Integrated household survey (IHS), 2016
# 2            Integrated household survey (IHS), 2016
# 3     Expenditure survey/budget survey (ES/BS), 2010
# 4                           Income survey (IS), 2015
#
#    Vital registration complete Latest agricultural census  \
# 0                          Yes                       2012
# 1                          Yes                       2008
# 2                          Yes                       2014
# 3                          Yes                  2015-2016
# 4                          Yes                       2010
#
#   Latest industrial data Latest trade data Latest water withdrawal data  \
# 0                 2013.0            2018.0                       2006.0
# 1                 2002.0            2018.0                       2011.0
# 2                    NaN            2018.0                       2012.0
# 3                 2013.0            2018.0                       2013.0
# 4                 2014.0            2018.0                       2010.0
#
#   2-alpha code WB-2 code Table Name Short Name
# 0           AL        AL    Albania    Albania
# 1           AR        AR  Argentina  Argentina
# 2           AM        AM    Armenia    Armenia
# 3           AU        AU  Australia  Australia
# 4           AT        AT    Austria    Austria
#
# [5 rows x 31 columns]

# %%
AccountsCountry_1 = AccountsCountry[['Code','Long Name','Income Group','Table Name','Currency Unit']]
AccountsCountry_1.head()
# Out:
#   Code                  Long Name         Income Group Table Name  \
# 0  ALB        Republic of Albania  Upper middle income    Albania
# 1  ARG         Argentine Republic  Upper middle income  Argentina
# 2  ARM        Republic of Armenia  Upper middle income    Armenia
# 3  AUS  Commonwealth of Australia          High income  Australia
# 4  AUT        Republic of Austria          High income    Austria
#
#        Currency Unit
# 0       Albanian lek
# 1     Argentine peso
# 2      Armenian dram
# 3  Australian dollar
# 4               Euro

# %%
#reading Wealth Data
WealthData = pd.read_csv('Data/AccountData.csv')
WealthData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# 4      4893.006      4737.857      4059.321      4191.445      4536.972
#
#   2000 [YR2000]  ... 2009 [YR2009] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 0      4.36E+10  ...  6.610000e+10  6.810000e+10  6.850000e+10  7.080000e+10
# 1      14118.13  ...  2.258200e+04  2.336286e+04  2.359058e+04  2.439397e+04
# 2      3424.007  ...  2.825336e+03  2.889150e+03  2.848523e+03  2.930234e+03
# 3      6872.019  ...  1.525319e+04  1.578992e+04  1.579854e+04  1.647360e+04
# 4      4695.071  ...  3.529144e+03  3.613606e+03  3.603694e+03  3.683810e+03
#
#    2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# 0   7.160000e+10   7.250000e+10   7.370000e+10       7.57E+10       7.80E+10
# 1   2.473162e+04   2.509002e+04   2.559371e+04       26326.26       27160.86
# 2   2.954273e+03   2.957420e+03   2.987545e+03       3072.504       3178.417
# 3   1.681013e+04   1.699138e+04   1.730701e+04        17817.1       18445.94
# 4   3.696744e+03   3.719608e+03   3.767628e+03       3872.142       3992.188
#
#    2018 [YR2018]
# 0       8.12E+10
# 1       28333.68
# 2       3312.927
# 3       19245.19
# 4       4161.137
#
# [5 rows x 28 columns]

# %%
WealthData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountsSeries = pd.read_csv('Data/AccountSeries.csv')
AccountsSeries.head()
AccountsSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountsSeries = AccountsSeries[['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
       'Unit of measure']]
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 2  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 3  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 4  World Bank. 2021. The Changing Wealth of Natio...  Human capital
#
#      Unit of measure
# 0  Constant 2018 US$
# 1  Constant 2018 US$
# 2  Constant 2018 US$
# 3  Constant 2018 US$
# 4  Constant 2018 US$

# %%
cur.close()
conn.close()
#Create Database
cur, conn = create_database()

# %%
AccountsCountry_1.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Table Name', 'Currency Unit'], dtype='object')

# %%
WealthData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountsSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure'],
#       dtype='object')

# %% [markdown]
# +--------------+             +--------------+
# |   Indicator  |             |    Country   |
# +--------------+             +--------------+
# |    Code (PK) |             |     Code (PK)|
# | Indicator Name|             |   Long Name  |
# |Long definition|             | Income Group |
# |    Source    |             |  Table Name  |
# |    Topic     |             |Currency Unit |
# |Unit of measure|             +--------------+
# +--------------+                     |1
#        |                              |
#        |                              |
#        |                              |
#        |                              |
# +--------------+                     |
# |   Indicator  |1              *+--------------+
# +--------------+<-------------|  CountryData |
# |    Code (FK) |              +--------------+
# |  Year (FK)   |              |  Country Code|
# |   Value      |              | Series Code  |
# +--------------+              |   Value      |
#                                +--------------+

# %%
#Create Indicator Table
indicator_table_create = ("""
CREATE TABLE IF NOT EXISTS indicator (
    Code VARCHAR(255) PRIMARY KEY,
    IndicatorName VARCHAR(255),
    LongDefinition TEXT,
    Source VARCHAR(255),
    Topic VARCHAR(255),
    UnitOfMeasure VARCHAR(255)
);
""")

# %%
cur.execute(indicator_table_create)
conn.commit()

# %%
#create country table
country_table_create = ("""
CREATE TABLE IF NOT EXISTS country (
    Code VARCHAR(255) PRIMARY KEY,
    LongName VARCHAR(255),
    IncomeGroup VARCHAR(255),
    TableName VARCHAR(255),
    CurrencyUnit VARCHAR(255)
);
""")

# %%
cur.execute(country_table_create)
conn.commit()

# %%
#create country data table
country_data_table_create = ("""
CREATE TABLE IF NOT EXISTS CountryData (
    "Indicator Code" VARCHAR(255),
    "Year" INT,
    "Country Code" VARCHAR(255),
    "Series Code" VARCHAR(255),
    "Value" FLOAT,
    FOREIGN KEY ("Indicator Code") REFERENCES Indicator(Code),
    FOREIGN KEY ("Country Code") REFERENCES Country(Code),
    PRIMARY KEY ("Indicator Code", "Year", "Country Code")
);
""")

# %%
cur.execute(country_data_table_create)
conn.commit()

# %% [markdown]
# Inserting data

# %%
indicator_table_insert = ("""
INSERT INTO indicator (
        Code, 
        IndicatorName, 
        LongDefinition, 
        Source, 
        Topic, 
        UnitOfMeasure)
VALUES (%s, %s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsSeries.iterrows():
    cur.execute(indicator_table_insert, row)
# Out:
# C:\Users\sh_bi\AppData\Local\Temp\ipykernel_1916\3431450552.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cur.execute(indicator_table_insert, row)
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[140], line 2
#       1 for i, row in AccountsSeries.iterrows():
# ----> 2     cur.execute(indicator_table_insert, row)
#
# UniqueViolation: duplicate key value violates unique constraint "indicator_pkey"
# DETAIL:  Key (code)=(NW.HCA.TO) already exists.

# %%
conn.commit()

# %%
query = "SELECT * FROM indicator"
cur.execute(query)
cur.fetchall()
# Out:
# [('NW.HCA.TO',
#   'Human capital (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.PC',
#   'Human capital per capita (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.FEMP.PC',
#   'Human capital per capita, employed female (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.MEMP.PC',
#   'Human capital per capita, employed male (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.FEMA.PC',
#   'Human capital per capita, female (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.MALE.PC',
#   'Human capital per capita, male (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.FSEM.PC',
#   'Human capital per capita, self-employed female (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.MSEM.PC',
#   'Human capital per capita, self-employed male (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.FEMP.TO',
#   'Human capital, employed female (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.MEMP.TO',
#   'Human capital, employed male (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.FEMA.TO',
#   'Human capital, female (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.MALE.TO',
#   'Human capital, male (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.FSEM.TO',
#   'Human capital, self-employed female (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.HCA.MSEM.TO',
#   'Human capital, self-employed male (constant 2018 US$)',
#   'Human capital is computed as the present value of future earnings for the working population over their lifetimes. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Human capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.TO',
#   'Natural capital (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.PC',
#   'Natural capital per capita (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.AGRI.PC',
#   'Natural capital per capita, agricultural land (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.CROL.PC',
#   'Natural capital per capita, agricultural land: cropland (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.PASL.PC',
#   'Natural capital per capita, agricultural land: pastureland (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FISH.PC',
#   'Natural capital per capita, fisheries (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FECO.PC',
#   'Natural capital per capita, forests: ecosystem services (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FTIM.PC',
#   'Natural capital per capita, forests: timber (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FOSL.PC',
#   'Natural capital per capita, fossil fuels (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.MANG.PC',
#   'Natural capital per capita, mangroves (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SSOI.PC',
#   'Natural capital per capita, nonrenewable assets (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SACO.PC',
#   'Natural capital per capita, nonrenewable assets: coal (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SAGA.PC',
#   'Natural capital per capita, nonrenewable assets: gas (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.MINR.PC',
#   'Natural capital per capita, nonrenewable assets: minerals (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SAOI.PC',
#   'Natural capital per capita, nonrenewable assets: oil (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.PRAR.PC',
#   'Natural capital per capita, protected areas (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.RNEW.PC',
#   'Natural capital per capita, renewable (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.AGRI.TO',
#   'Natural capital, agricultural land (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.CROL.TO',
#   'Natural capital, agricultural land: cropland (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.PASL.TO',
#   'Natural capital, agricultural land: pastureland (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FISH.TO',
#   'Natural capital, fisheries (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FECO.TO',
#   'Natural capital, forests: ecosystem services (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FTIM.TO',
#   'Natural capital, forests: timber (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.FOSL.TO',
#   'Natural capital, fossil fuels (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.MANG.TO',
#   'Natural capital, mangroves (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SSOI.TO',
#   'Natural capital, nonrenewable assets (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SACO.TO',
#   'Natural capital, nonrenewable assets: coal (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SAGA.TO',
#   'Natural capital, nonrenewable assets: gas (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.MINR.TO',
#   'Natural capital, nonrenewable assets: minerals (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.SAOI.TO',
#   'Natural capital, nonrenewable assets: oil (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.PRAR.TO',
#   'Natural capital, protected areas (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NCA.RNEW.TO',
#   'Natural capital, renewable (constant 2018 US$)',
#   'Natural capital includes the valuation of renewable and nonrenewable natural capital. Renewable natural capital includes agricultural land (cropland and pastureland), forests (timber, and three ecosystem services: water, recretion and non-wood forest products), protected areas, mangroves and fisheries. Nonrenewable natural capital includes fossil fuel energy (oil, gas, hard and soft coal) and minerals (bauxite, copper, gold, iron ore, lead, nickel, phosphate, silver, tin, and zinc),Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Natural capital',
#   'Constant 2018 US$'),
#  ('NW.NFA.TO',
#   'Net foreign assets (constant 2018 US$)',
#   'Net foreign assets is foreign assets minus foreign liabilities. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Net foreign assets',
#   'Constant 2018 US$'),
#  ('NW.NFA.PC',
#   'Net foreign assets per capita (constant 2018 US$)',
#   'Net foreign assets is foreign assets minus foreign liabilities. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Net foreign assets',
#   'Constant 2018 US$'),
#  ('NW.PCA.TO',
#   'Produced capital (constant 2018 US$)',
#   'Produced capital includes the value of machinery, buildings, equipment, and residential and nonresidential urban land. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Produced capital',
#   'Constant 2018 US$'),
#  ('NW.PCA.PC',
#   'Produced capital per capita (constant 2018 US$)',
#   'Produced capital includes the value of machinery, buildings, equipment, and residential and nonresidential urban land. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Produced capital',
#   'Constant 2018 US$'),
#  ('NW.TOW.TO',
#   'Total wealth (constant 2018 US$)',
#   'Total wealth is calculated as the sum of produced capital, natural capital, human capital, and net foreign assets. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Total wealth',
#   'Constant 2018 US$'),
#  ('NW.TOW.PC',
#   'Total wealth per capita (constant 2018 US$)',
#   'Total wealth is calculated as the sum of produced capital, natural capital, human capital, and net foreign assets. Values are measured at market exchange rates in constant 2018 US dollars, using a country-specific GDP deflator.',
#   'World Bank. 2021. The Changing Wealth of Nations 2021: Managing Assets for the Future. Washington, DC: World Bank. doi:10.1596/978-1-4648-1590-4.',
#   'Total wealth',
#   'Constant 2018 US$')]

# %%
country_table_insert = ("""
INSERT INTO country (
        Code, 
        LongName, 
        IncomeGroup, 
        TableName, 
        CurrencyUnit)
VALUES (%s, %s, %s, %s, %s)
ON CONFLICT (code) DO NOTHING;
""")

# %%
AccountsCountry_1.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Table Name', 'Currency Unit'], dtype='object')

# %%
for i, row in AccountsCountry_1.iterrows():
    cur.execute(country_table_insert, row)

query = "SELECT * FROM country"
# Out:
# C:\Users\sh_bi\AppData\Local\Temp\ipykernel_1916\4064467178.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cur.execute(country_table_insert, row)

# %%
query = "SELECT * FROM country"
cur.execute(query)
cur.fetchall()
# Out:
# [('ALB',
#   'Republic of Albania',
#   'Upper middle income',
#   'Albania',
#   'Albanian lek'),
#  ('ARG',
#   'Argentine Republic',
#   'Upper middle income',
#   'Argentina',
#   'Argentine peso'),
#  ('ARM',
#   'Republic of Armenia',
#   'Upper middle income',
#   'Armenia',
#   'Armenian dram'),
#  ('AUS',
#   'Commonwealth of Australia',
#   'High income',
#   'Australia',
#   'Australian dollar'),
#  ('AUT', 'Republic of Austria', 'High income', 'Austria', 'Euro'),
#  ('AZE',
#   'Republic of Azerbaijan',
#   'Upper middle income',
#   'Azerbaijan',
#   'New Azeri manat'),
#  ('BHR', 'Kingdom of Bahrain', 'High income', 'Bahrain', 'Bahraini dinar'),
#  ('BGD',
#   "People's Republic of Bangladesh",
#   'Lower middle income',
#   'Bangladesh',
#   'Bangladeshi taka'),
#  ('BLR',
#   'Republic of Belarus',
#   'Upper middle income',
#   'Belarus',
#   'Belarusian rubel'),
#  ('BEL', 'Kingdom of Belgium', 'High income', 'Belgium', 'Euro'),
#  ('BLZ', 'Belize', 'Lower middle income', 'Belize', 'Belize dollar'),
#  ('BEN',
#   'Republic of Benin',
#   'Lower middle income',
#   'Benin',
#   'West African CFA franc'),
#  ('BOL',
#   'Plurinational State of Bolivia',
#   'Lower middle income',
#   'Bolivia',
#   'Bolivian Boliviano'),
#  ('BIH',
#   'Bosnia and Herzegovina',
#   'Upper middle income',
#   'Bosnia and Herzegovina',
#   'Bosnia and Herzegovina convertible mark'),
#  ('BWA',
#   'Republic of Botswana',
#   'Upper middle income',
#   'Botswana',
#   'Botswana pula'),
#  ('BRA',
#   'Federative Republic of Brazil',
#   'Upper middle income',
#   'Brazil',
#   'Brazilian real'),
#  ('BGR',
#   'Republic of Bulgaria',
#   'Upper middle income',
#   'Bulgaria',
#   'Bulgarian lev'),
#  ('BFA',
#   'Burkina Faso',
#   'Low income',
#   'Burkina Faso',
#   'West African CFA franc'),
#  ('BDI', 'Republic of Burundi', 'Low income', 'Burundi', 'Burundi franc'),
#  ('KHM',
#   'Kingdom of Cambodia',
#   'Lower middle income',
#   'Cambodia',
#   'Cambodian riel'),
#  ('CMR',
#   'Republic of Cameroon',
#   'Lower middle income',
#   'Cameroon',
#   'Central African CFA franc'),
#  ('CAN', 'Canada', 'High income', 'Canada', 'Canadian dollar'),
#  ('CAF',
#   'Central African Republic',
#   'Low income',
#   'Central African Republic',
#   'Central African CFA franc'),
#  ('TCD',
#   'Republic of Chad',
#   'Low income',
#   'Chad',
#   'Central African CFA franc'),
#  ('CHL', 'Republic of Chile', 'High income', 'Chile', 'Chilean peso'),
#  ('CHN',
#   "People's Republic of China",
#   'Upper middle income',
#   'China',
#   'Chinese yuan'),
#  ('COL',
#   'Republic of Colombia',
#   'Upper middle income',
#   'Colombia',
#   'Colombian peso'),
#  ('COM',
#   'Union of the Comoros',
#   'Lower middle income',
#   'Comoros',
#   'Comorian franc'),
#  ('COG',
#   'Republic of Congo',
#   'Lower middle income',
#   'Congo, Rep.',
#   'Central African CFA franc'),
#  ('CRI',
#   'Republic of Costa Rica',
#   'Upper middle income',
#   'Costa Rica',
#   'Costa Rican colon'),
#  ('CIV',
#   "Republic of Côte d'Ivoire",
#   'Lower middle income',
#   "Côte d'Ivoire",
#   'West African CFA franc'),
#  ('HRV', 'Republic of Croatia', 'High income', 'Croatia', 'Croatian kuna'),
#  ('CZE', 'Czech Republic', 'High income', 'Czech Republic', 'Czech koruna'),
#  ('COD',
#   'Democratic Republic of the Congo',
#   'Low income',
#   'Congo, Dem. Rep.',
#   'Congolese franc'),
#  ('DNK', 'Kingdom of Denmark', 'High income', 'Denmark', 'Danish krone'),
#  ('DJI',
#   'Republic of Djibouti',
#   'Lower middle income',
#   'Djibouti',
#   'Djibouti franc'),
#  ('DOM',
#   'Dominican Republic',
#   'Upper middle income',
#   'Dominican Republic',
#   'Dominican peso'),
#  ('ECU',
#   'Republic of Ecuador',
#   'Upper middle income',
#   'Ecuador',
#   'U.S. dollar'),
#  ('EGY',
#   'Arab Republic of Egypt',
#   'Lower middle income',
#   'Egypt, Arab Rep.',
#   'Egyptian pound'),
#  ('SLV',
#   'Republic of El Salvador',
#   'Lower middle income',
#   'El Salvador',
#   'U.S. dollar'),
#  ('EST', 'Republic of Estonia', 'High income', 'Estonia', 'Euro'),
#  ('SWZ',
#   'Kingdom of Eswatini',
#   'Lower middle income',
#   'Eswatini',
#   'Swazi lilangeni'),
#  ('ETH',
#   'Federal Democratic Republic of Ethiopia',
#   'Low income',
#   'Ethiopia',
#   'Ethiopian birr'),
#  ('FIN', 'Republic of Finland', 'High income', 'Finland', 'Euro'),
#  ('FRA', 'French Republic', 'High income', 'France', 'Euro'),
#  ('GAB',
#   'Gabonese Republic',
#   'Upper middle income',
#   'Gabon',
#   'Central African CFA franc'),
#  ('GEO', 'Georgia', 'Upper middle income', 'Georgia', 'Georgian lari'),
#  ('DEU', 'Federal Republic of Germany', 'High income', 'Germany', 'Euro'),
#  ('GHA',
#   'Republic of Ghana',
#   'Lower middle income',
#   'Ghana',
#   'New Ghanaian cedi'),
#  ('GRC', 'Hellenic Republic', 'High income', 'Greece', 'Euro'),
#  ('GTM',
#   'Republic of Guatemala',
#   'Upper middle income',
#   'Guatemala',
#   'Guatemalan quetzal'),
#  ('GIN', 'Republic of Guinea', 'Low income', 'Guinea', 'Guinean franc'),
#  ('GUY',
#   'Co-operative Republic of Guyana',
#   'Upper middle income',
#   'Guyana',
#   'Guyana dollar'),
#  ('HTI',
#   'Republic of Haiti',
#   'Lower middle income',
#   'Haiti',
#   'Haitian gourde'),
#  ('HND',
#   'Republic of Honduras',
#   'Lower middle income',
#   'Honduras',
#   'Honduran lempira'),
#  ('HUN', 'Hungary', 'High income', 'Hungary', 'Hungarian forint'),
#  ('ISL', 'Republic of Iceland', 'High income', 'Iceland', 'Iceland krona'),
#  ('IND', 'Republic of India', 'Lower middle income', 'India', 'Indian rupee'),
#  ('IDN',
#   'Republic of Indonesia',
#   'Lower middle income',
#   'Indonesia',
#   'Indonesian rupiah'),
#  ('IRN',
#   'Islamic Republic of Iran',
#   'Lower middle income',
#   'Iran, Islamic Rep.',
#   'Iranian rial'),
#  ('IRQ', 'Republic of Iraq', 'Upper middle income', 'Iraq', 'Iraqi dinar'),
#  ('IRL', 'Ireland', 'High income', 'Ireland', 'Euro'),
#  ('ITA', 'Italian Republic', 'High income', 'Italy', 'Euro'),
#  ('JAM', 'Jamaica', 'Upper middle income', 'Jamaica', 'Jamaican dollar'),
#  ('JPN', 'Japan', 'High income', 'Japan', 'Japanese yen'),
#  ('JOR',
#   'Hashemite Kingdom of Jordan',
#   'Upper middle income',
#   'Jordan',
#   'Jordanian dinar'),
#  ('KAZ',
#   'Republic of Kazakhstan',
#   'Upper middle income',
#   'Kazakhstan',
#   'Kazakh tenge'),
#  ('KEN',
#   'Republic of Kenya',
#   'Lower middle income',
#   'Kenya',
#   'Kenyan shilling'),
#  ('KOR', 'Republic of Korea', 'High income', 'Korea, Rep.', 'Korean won'),
#  ('KWT', 'State of Kuwait', 'High income', 'Kuwait', 'Kuwaiti dinar'),
#  ('KGZ',
#   'Kyrgyz Republic',
#   'Lower middle income',
#   'Kyrgyz Republic',
#   'Kyrgyz som'),
#  ('LAO',
#   "Lao People's Democratic Republic",
#   'Lower middle income',
#   'Lao PDR',
#   'Lao kip'),
#  ('LVA', 'Republic of Latvia', 'High income', 'Latvia', 'Euro'),
#  ('LBN',
#   'Lebanese Republic',
#   'Upper middle income',
#   'Lebanon',
#   'Lebanese pound'),
#  ('LSO',
#   'Kingdom of Lesotho',
#   'Lower middle income',
#   'Lesotho',
#   'Lesotho loti'),
#  ('LBR', 'Republic of Liberia', 'Low income', 'Liberia', 'U.S. dollar'),
#  ('LTU', 'Republic of Lithuania', 'High income', 'Lithuania', 'Euro'),
#  ('LUX', 'Grand Duchy of Luxembourg', 'High income', 'Luxembourg', 'Euro'),
#  ('MDG',
#   'Republic of Madagascar',
#   'Low income',
#   'Madagascar',
#   'Malagasy ariary'),
#  ('MWI', 'Republic of Malawi', 'Low income', 'Malawi', 'Malawi kwacha'),
#  ('MYS', 'Malaysia', 'Upper middle income', 'Malaysia', 'Malaysian ringgit'),
#  ('MDV',
#   'Republic of Maldives',
#   'Upper middle income',
#   'Maldives',
#   'Maldivian rufiyaa'),
#  ('MLI', 'Republic of Mali', 'Low income', 'Mali', 'West African CFA franc'),
#  ('MLT', 'Republic of Malta', 'High income', 'Malta', 'Euro'),
#  ('MRT',
#   'Islamic Republic of Mauritania',
#   'Lower middle income',
#   'Mauritania',
#   'Mauritanian ouguiya'),
#  ('MUS',
#   'Republic of Mauritius',
#   'Upper middle income',
#   'Mauritius',
#   'Mauritian rupee'),
#  ('MEX',
#   'United Mexican States',
#   'Upper middle income',
#   'Mexico',
#   'Mexican peso'),
#  ('MDA',
#   'Republic of Moldova',
#   'Upper middle income',
#   'Moldova',
#   'Moldovan leu'),
#  ('MNG', 'Mongolia', 'Lower middle income', 'Mongolia', 'Mongolian tugrik'),
#  ('MAR',
#   'Kingdom of Morocco',
#   'Lower middle income',
#   'Morocco',
#   'Moroccan dirham'),
#  ('MOZ',
#   'Republic of Mozambique',
#   'Low income',
#   'Mozambique',
#   'New Mozambican metical'),
#  ('NAM',
#   'Republic of Namibia',
#   'Upper middle income',
#   'Namibia',
#   'Namibian dollar'),
#  ('NPL', 'Nepal', 'Lower middle income', 'Nepal', 'Nepalese rupee'),
#  ('NLD', 'Kingdom of the Netherlands', 'High income', 'Netherlands', 'Euro'),
#  ('NIC',
#   'Republic of Nicaragua',
#   'Lower middle income',
#   'Nicaragua',
#   'Nicaraguan gold cordoba'),
#  ('NER', 'Republic of Niger', 'Low income', 'Niger', 'West African CFA franc'),
#  ('NGA',
#   'Federal Republic of Nigeria',
#   'Lower middle income',
#   'Nigeria',
#   'Nigerian naira'),
#  ('MKD',
#   'Republic of North Macedonia',
#   'Upper middle income',
#   'North Macedonia',
#   'Macedonian denar'),
#  ('NOR', 'Kingdom of Norway', 'High income', 'Norway', 'Norwegian krone'),
#  ('OMN', 'Sultanate of Oman', 'High income', 'Oman', 'Omani rial'),
#  ('PAK',
#   'Islamic Republic of Pakistan',
#   'Lower middle income',
#   'Pakistan',
#   'Pakistani rupee'),
#  ('PAN',
#   'Republic of Panama',
#   'Upper middle income',
#   'Panama',
#   'Panamanian balboa'),
#  ('PNG',
#   'The Independent State of Papua New Guinea',
#   'Lower middle income',
#   'Papua New Guinea',
#   'Papua New Guinea kina'),
#  ('PRY',
#   'Republic of Paraguay',
#   'Upper middle income',
#   'Paraguay',
#   'Paraguayan guarani'),
#  ('PER',
#   'Republic of Peru',
#   'Upper middle income',
#   'Peru',
#   'Peruvian new sol'),
#  ('PHL',
#   'Republic of the Philippines',
#   'Lower middle income',
#   'Philippines',
#   'Philippine peso'),
#  ('POL', 'Republic of Poland', 'High income', 'Poland', 'Polish zloty'),
#  ('PRT', 'Portuguese Republic', 'High income', 'Portugal', 'Euro'),
#  ('QAT', 'State of Qatar', 'High income', 'Qatar', 'Qatari riyal'),
#  ('ROU', 'Romania', 'Upper middle income', 'Romania', 'New Romanian leu'),
#  ('RUS',
#   'Russian Federation',
#   'Upper middle income',
#   'Russian Federation',
#   'Russian ruble'),
#  ('RWA', 'Republic of Rwanda', 'Low income', 'Rwanda', 'Rwandan franc'),
#  ('SAU',
#   'Kingdom of Saudi Arabia',
#   'High income',
#   'Saudi Arabia',
#   'Saudi Arabian riyal'),
#  ('SEN',
#   'Republic of Senegal',
#   'Lower middle income',
#   'Senegal',
#   'West African CFA franc'),
#  ('SLE',
#   'Republic of Sierra Leone',
#   'Low income',
#   'Sierra Leone',
#   'Sierra Leonean leone'),
#  ('SGP',
#   'Republic of Singapore',
#   'High income',
#   'Singapore',
#   'Singapore dollar'),
#  ('SVK', 'Slovak Republic', 'High income', 'Slovak Republic', 'Euro'),
#  ('SVN', 'Republic of Slovenia', 'High income', 'Slovenia', 'Euro'),
#  ('SLB',
#   'Solomon Islands',
#   'Lower middle income',
#   'Solomon Islands',
#   'Solomon Islands dollar'),
#  ('ZAF',
#   'Republic of South Africa',
#   'Upper middle income',
#   'South Africa',
#   'South African rand'),
#  ('ESP', 'Kingdom of Spain', 'High income', 'Spain', 'Euro'),
#  ('LKA',
#   'Democratic Socialist Republic of Sri Lanka',
#   'Lower middle income',
#   'Sri Lanka',
#   'Sri Lankan rupee'),
#  ('SUR',
#   'Republic of Suriname',
#   'Upper middle income',
#   'Suriname',
#   'Suriname dollar'),
#  ('SWE', 'Kingdom of Sweden', 'High income', 'Sweden', 'Swedish krona'),
#  ('CHE', 'Switzerland', 'High income', 'Switzerland', 'Swiss franc'),
#  ('TJK',
#   'Republic of Tajikistan',
#   'Lower middle income',
#   'Tajikistan',
#   'Tajik somoni'),
#  ('TZA',
#   'United Republic of Tanzania',
#   'Lower middle income',
#   'Tanzania',
#   'Tanzanian shilling'),
#  ('THA',
#   'Kingdom of Thailand',
#   'Upper middle income',
#   'Thailand',
#   'Thai baht'),
#  ('GMB',
#   'Republic of The Gambia',
#   'Low income',
#   'Gambia, The',
#   'Gambian dalasi'),
#  ('TGO', 'Republic of Togo', 'Low income', 'Togo', 'West African CFA franc'),
#  ('TTO',
#   'Republic of Trinidad and Tobago',
#   'High income',
#   'Trinidad and Tobago',
#   'Trinidad and Tobago dollar'),
#  ('TUN',
#   'Republic of Tunisia',
#   'Lower middle income',
#   'Tunisia',
#   'Tunisian dinar'),
#  ('TUR',
#   'Republic of Turkey',
#   'Upper middle income',
#   'Turkey',
#   'New Turkish lira'),
#  ('TKM',
#   'Turkmenistan',
#   'Upper middle income',
#   'Turkmenistan',
#   'New Turkmen manat'),
#  ('UGA', 'Republic of Uganda', 'Low income', 'Uganda', 'Ugandan shilling'),
#  ('UKR', 'Ukraine', 'Lower middle income', 'Ukraine', 'Ukrainian hryvnia'),
#  ('ARE',
#   'United Arab Emirates',
#   'High income',
#   'United Arab Emirates',
#   'U.A.E. dirham'),
#  ('GBR',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'High income',
#   'United Kingdom',
#   'Pound sterling'),
#  ('USA',
#   'United States of America',
#   'High income',
#   'United States',
#   'U.S. dollar'),
#  ('URY',
#   'Oriental Republic of Uruguay',
#   'High income',
#   'Uruguay',
#   'Uruguayan peso'),
#  ('VEN',
#   'República Bolivariana de Venezuela',
#   'NaN',
#   'Venezuela, RB',
#   'Venezuelan bolivar fuerte'),
#  ('VNM',
#   'Socialist Republic of Vietnam',
#   'Lower middle income',
#   'Vietnam',
#   'Vietnamese dong'),
#  ('PSE',
#   'West Bank and Gaza',
#   'Lower middle income',
#   'West Bank and Gaza',
#   'Israeli new shekel'),
#  ('YEM', 'Republic of Yemen', 'Low income', 'Yemen, Rep.', 'Yemeni rial'),
#  ('ZMB',
#   'Republic of Zambia',
#   'Lower middle income',
#   'Zambia',
#   'New Zambian kwacha'),
#  ('ZWE',
#   'Republic of Zimbabwe',
#   'Lower middle income',
#   'Zimbabwe',
#   'U.S. dollar'),
#  ('NaN', 'NaN', 'NaN', 'NaN', 'NaN')]

# %%
conn.commit()

# %%
country_data_table_insert = ("""
INSERT INTO CountryData ("Indicator Code", "Year", "Country Code", "Series Code", "Value")
    VALUES (%s, %s, %s, %s, %s)
""")

# %%
WealthData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
for index, row in WealthData.iterrows():
    # Extract the common columns from the row
    country_code = row['Country Code']
    series_code = row['Series Code']
    
    # Iterate over the columns representing years
    for year_column in WealthData.columns[4:]:
        year = year_column.split('[YR')[1][:-1]  # Extract the year from the column name
        value = row[year_column]
        
        # Insert the values into the CountryData table
        values = (indicator_code, year, country_code, series_code, value)
        cur.execute(country_data_table_insert, values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 12
#       9 value = row[year_column]
#      11 # Insert the values into the CountryData table
# ---> 12 values = (indicator_code, year, country_code, series_code, value)
#      13 cur.execute(country_data_table_insert, values)
#
# NameError: name 'indicator_code' is not defined
